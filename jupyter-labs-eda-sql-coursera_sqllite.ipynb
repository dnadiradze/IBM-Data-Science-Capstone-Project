# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %%
# !pip install sqlalchemy==1.3.9
# Out:
# Collecting sqlalchemy==1.3.9
#   Using cached sqlalchemy-1.3.9-cp313-cp313-win_amd64.whl
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.51
#     Uninstalling SQLAlchemy-2.0.51:
#       Successfully uninstalled SQLAlchemy-2.0.51
# Successfully installed sqlalchemy-1.3.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aext-project-filebrowser-server 4.20.0 requires sqlalchemy>=2.0.29, but you have sqlalchemy 1.3.9 which is incompatible.
# alembic 1.18.4 requires SQLAlchemy>=1.4.23, but you have sqlalchemy 1.3.9 which is incompatible.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.3.9 which is incompatible.

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# !pip install ipython-sql
# !pip install ipython-sql prettytable
# Out:
# Requirement already satisfied: ipython-sql in c:\users\family\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\family\anaconda3\lib\site-packages (from ipython-sql) (3.18.0)
# Requirement already satisfied: ipython in c:\users\family\anaconda3\lib\site-packages (from ipython-sql) (9.7.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\family\anaconda3\lib\site-packages (from ipython-sql) (2.0.51)
# Requirement already satisfied: sqlparse in c:\users\family\anaconda3\lib\site-packages (from ipython-sql) (0.5.5)
# Requirement already satisfied: six in c:\users\family\anaconda3\lib\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in c:\users\family\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in c:\users\family\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\family\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\family\anaconda3\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\family\anaconda3\lib\site-packages (from jedi>=0.18.1->ipython->ipython-sql) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\family\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\family\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\family\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (0.2.3)
# Requirement already satisfied: ipython-sql in c:\users\family\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\family\anaconda3\lib\site-packages (3.18.0)
# Requirement already satisfied: ipython in c:\users\family\anaconda3\lib\site-packages (from ipython-sql) (9.7.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\family\anaconda3\lib\site-packages (from ipython-sql) (2.0.51)
# Requirement already satisfied: sqlparse in c:\users\family\anaconda3\lib\site-packages (from ipython-sql) (0.5.5)
# Requirement already satisfied: six in c:\users\family\anaconda3\lib\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in c:\users\family\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: wcwidth>=0.3.5 in c:\users\family\anaconda3\lib\site-packages (from prettytable) (0.8.2)
# Requirement already satisfied: greenlet>=1 in c:\users\family\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\family\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\family\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\family\anaconda3\lib\site-packages (from jedi>=0.18.1->ipython->ipython-sql) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\family\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\family\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\family\anaconda3\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (0.2.3)

# %%
# %load_ext sql

# %%
import csv, sqlite3
import prettytable
prettytable.DEFAULT = 'DEFAULT'

con = sqlite3.connect("my_data1.db")
cur = con.cursor()

# %%
# !pip install -q pandas

# %%
# %sql sqlite:///my_data1.db

# %%
import pandas as pd
df = pd.read_csv("dataset_part_2.csv")
df.to_sql("SPACEXTBL", con, if_exists='replace', index=False,method="multi")
# Out:
# 121

# %% [markdown]
# **Note:This below code is added to remove blank rows from table**

# %%
#DROP THE TABLE IF EXISTS

# %sql DROP TABLE IF EXISTS SPACEXTABLE;
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %%
# %sql create table SPACEXTABLE as select * from SPACEXTBL where Date is not null
# Out:
#  * sqlite:///my_data1.db
# Done.
# []

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
#    For Example "Landing_Outcome"**
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
# %%sql
#
# SELECT DISTINCT "Launch site"
# FROM SPACEXTABLE;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('CCAFS',), ('VAFB',), ('Cape Canaveral',), ('KSC',), ('CCSFS',)]

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %%
# %%sql
#
# SELECT *
# FROM SPACEXTABLE
# WHERE "Launch site" LIKE 'CCA%'
# LIMIT 5;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(1, 'CCAFS', 'Dragon Spacecraft Qualification Unit', '0', 'LEO', 'SpaceX', 'Success', 'F9 v1.07B0003.1', 'Failure', '4 June 2010', '18:45', 0),
#  (2, 'CCAFS', 'Dragon', '0', 'LEO', 'NASA', 'Success', 'F9 v1.07B0004.1', 'Failure', '8 December 2010', '15:43', 0),
#  (3, 'CCAFS', 'Dragon', '525 kg', 'LEO', 'NASA', 'Success', 'F9 v1.07B0005.1', 'No', '22 May 2012', '07:44', 1),
#  (4, 'CCAFS', 'SpaceX CRS-1', '4,700 kg', 'LEO', 'NASA', 'Success', 'F9 v1.07B0006.1', 'No attempt', '8 October 2012', '00:35', 1),
#  (5, 'CCAFS', 'SpaceX CRS-2', '4,877 kg', 'LEO', 'NASA', 'Success', 'F9 v1.07B0007.1', 'No', '1 March 2013', '15:10', 1)]

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
# %%sql
#
# SELECT SUM("Payload mass") AS Total_Payload_Mass
# FROM SPACEXTABLE
# WHERE Customer = 'NASA'
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(1525.0,)]

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
# %%sql
#
# SELECT AVG("Payload mass") AS Average_Payload_Mass
# FROM SPACEXTABLE
# WHERE "Version Booster" = 'F9 v1.1';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(2.6,)]

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %%
# %%sql
#
# SELECT MIN(Date) AS First_Successful_Landing_Date
# FROM SPACEXTABLE
# WHERE "Booster landing" = 'Success';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('1 May 2017',)]

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
# %%sql
#
# PRAGMA table_info(SPACEXTABLE);
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(0, 'Flight No.', 'INT', 0, None, 0),
#  (1, 'Launch site', 'TEXT', 0, None, 0),
#  (2, 'Payload', 'TEXT', 0, None, 0),
#  (3, 'Payload mass', 'TEXT', 0, None, 0),
#  (4, 'Orbit', 'TEXT', 0, None, 0),
#  (5, 'Customer', 'TEXT', 0, None, 0),
#  (6, 'Launch outcome', 'TEXT', 0, None, 0),
#  (7, 'Version Booster', 'TEXT', 0, None, 0),
#  (8, 'Booster landing', 'TEXT', 0, None, 0),
#  (9, 'Date', 'TEXT', 0, None, 0),
#  (10, 'Time', 'TEXT', 0, None, 0),
#  (11, 'Class', 'INT', 0, None, 0)]

# %%
# %%sql
#
# SELECT "Version Booster", "Payload mass"
# FROM SPACEXTABLE
# WHERE "Booster landing" = 'Success'
# AND "Payload mass" > 4000
# AND "Payload mass" < 6000;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 FT♺[', '5,300 kg'),
#  ('F9 FT[', '475 kg'),
#  ('F9 FTB1031.2', '5,200 kg'),
#  ('F9 B5B1046.2', '5,800 kg'),
#  ('F9 B5B1047.2', '5,300 kg'),
#  ('F9 B5B1056.3', '6,956 kg'),
#  ('F9 B5B1058.2', '5,000–6,000 kg')]

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %%
# %%sql
#
# SELECT "Launch outcome", COUNT(*) AS Total_Missions
# FROM SPACEXTABLE
# GROUP BY "Launch outcome";
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Failure', 1), ('Success', 120)]

# %% [markdown]
# ### Task 8
#
#
#
# ##### List all the booster_versions that have carried the maximum payload mass, using a subquery with a suitable aggregate function.

# %%
# %%sql
#
# SELECT "Version Booster", "Payload mass"
# FROM SPACEXTABLE
# WHERE "Payload mass" = (
#     SELECT MAX("Payload mass")
#     FROM SPACEXTABLE
# );
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('F9 B5B1058.5', '~5,000 kg')]

# %% [markdown]
# ### Task 9
#
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 6,2) as month to get the months and substr(Date,0,5)='2015' for year.**

# %%
# %%sql
#
# PRAGMA table_info(SPACEXTABLE);
# Out:
#  * sqlite:///my_data1.db
# Done.
# [(0, 'Flight No.', 'INT', 0, None, 0),
#  (1, 'Launch site', 'TEXT', 0, None, 0),
#  (2, 'Payload', 'TEXT', 0, None, 0),
#  (3, 'Payload mass', 'TEXT', 0, None, 0),
#  (4, 'Orbit', 'TEXT', 0, None, 0),
#  (5, 'Customer', 'TEXT', 0, None, 0),
#  (6, 'Launch outcome', 'TEXT', 0, None, 0),
#  (7, 'Version Booster', 'TEXT', 0, None, 0),
#  (8, 'Booster landing', 'TEXT', 0, None, 0),
#  (9, 'Date', 'TEXT', 0, None, 0),
#  (10, 'Time', 'TEXT', 0, None, 0),
#  (11, 'Class', 'INT', 0, None, 0)]

# %%
# %%sql
#
# SELECT
#     substr(Date, 6, 2) AS Month,
#     "Booster landing",
#     "Version Booster",
#     "Launch site"
# FROM SPACEXTABLE
# WHERE Date LIKE '%2015%'
# AND "Booster landing" = 'Failure';
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('ri', 'Failure', 'F9 v1.1[', 'Cape Canaveral')]

# %% [markdown]
# ### Task 10
#
#
#
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order.

# %%
# %%sql
#
# SELECT
#     "Booster landing",
#     COUNT(*) AS Total_Count
# FROM SPACEXTABLE
# WHERE Date LIKE '%2010%'
#    OR Date LIKE '%2011%'
#    OR Date LIKE '%2012%'
#    OR Date LIKE '%2013%'
#    OR Date LIKE '%2014%'
#    OR Date LIKE '%2015%'
#    OR Date LIKE '%2016%'
#    OR Date LIKE '%2017%'
# GROUP BY "Booster landing"
# ORDER BY Total_Count DESC;
# Out:
#  * sqlite:///my_data1.db
# Done.
# [('Success', 20),
#  ('No', 11),
#  ('Failure', 6),
#  ('Controlled', 4),
#  ('Uncontrolled', 2),
#  ('Precluded', 1),
#  ('No attempt', 1),
#  ('Failure ', 1)]

# %% [markdown]
# ### Reference Links
#
# * <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *  <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# <!--
# ## Change log
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2024-07-10 | 1.1 |Anita Verma | Changed Version|
# | 2021-07-09 | 0.2 |Lakshmi Holla | Changes made in magic sql|
# | 2021-05-20 | 0.1 |Lakshmi Holla | Created Initial Version |
# -->

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
